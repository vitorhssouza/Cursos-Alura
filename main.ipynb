# %% [markdown]
# ## Curso de python e request alura

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# [{'id': '34221561310',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 661535205,
#    'name': 'thedoggybrad/easylist-mirror',
#    'url': 'https://api.github.com/repos/thedoggybrad/easylist-mirror'},
#   'payload': {'repository_id': 661535205,
#    'push_id': 16306745156,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd3e4a3ccca98ecbf081415aba07f647a7aafb280',
#    'before': '90b4ea5b7cbc5f516651c5735dde62a3d25738fb',
#    'commits': [{'sha': 'd3e4a3ccca98ecbf081415aba07f647a7aafb280',
#      'author': {'email': '142152315+syncbot-easylistmirror@users.noreply.github.com',
#       'name': 'syncbot-easylistmirror'},
#      'message': 'Sync fanboy-cookiemonster.txt',
# ...

# %%
# Realizando requisição para extrair dados do meu github 

git = requests.get('https://api.github.com/users/vitorhssouza')

# %%
git.status_code
# Out:
# 200

# %%
git.json()
# Out:
# {'login': 'vitorhssouza',
#  'id': 96426356,
#  'node_id': 'U_kgDOBb9ZdA',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/96426356?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/vitorhssouza',
#  'html_url': 'https://github.com/vitorhssouza',
#  'followers_url': 'https://api.github.com/users/vitorhssouza/followers',
#  'following_url': 'https://api.github.com/users/vitorhssouza/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/vitorhssouza/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/vitorhssouza/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/vitorhssouza/subscriptions',
#  'organizations_url': 'https://api.github.com/users/vitorhssouza/orgs',
#  'repos_url': 'https://api.github.com/users/vitorhssouza/repos',
#  'events_url': 'https://api.github.com/users/vitorhssouza/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/vitorhssouza/received_events',
# ...

# %%
git.json()['public_repos']
# Out:
# 26

# %% [markdown]
# r = requests.get('https://api.github.com/events')
